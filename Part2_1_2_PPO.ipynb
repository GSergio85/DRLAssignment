# %%
# !pip install gymnasium gymnasium[mujoco]
# !pip install 'shimmy>=0.2.1'
# !pip install gymnasium
# !pip install -- upgrade stable - baselines3
# !pip install mujoco
# !pip install stable-baselines3
# !pip install stable-baselines3 gym tensorboard
# !apt-get install swig
# !pip install box2d
# !pip install gym[box2d]
# !pip install optuna
# Out:
# Collecting gymnasium
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Collecting mujoco>=2.3.3 (from gymnasium)
#   Downloading mujoco-3.1.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 21.2 MB/s eta 0:00:00
# Requirement already satisfied: imageio>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.31.6)
# Requirement already satisfied: pillow<10.1.0,>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio>=2.14.1->gymnasium) (9.4.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from mujoco>=2.3.3->gymnasium) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.10/dist-packages (from mujoco>=2.3.3->gymnasium) (1.7.0)
# Collecting glfw (from mujoco>=2.3.3->gymnasium)
#   Downloading glfw-2.7.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38-none-manylinux2014_x86_64.whl (211 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.8/211.8 kB 14.4 MB/s eta 0:00:00
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.10/dist-packages (from mujoco>=2.3.3->gymnasium) (3.1.7)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco>=2.3.3->gymnasium) (2023.6.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco>=2.3.3->gymnasium) (6.4.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco>=2.3.3->gymnasium) (3.19.2)
# Installing collected packages: glfw, farama-notifications, gymnasium, mujoco
# Successfully installed farama-notifications-0.0.4 glfw-2.7.0 gymnasium-0.29.1 mujoco-3.1.6
# Collecting shimmy>=0.2.1
#   Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from shimmy>=0.2.1) (1.25.2)
# Collecting gymnasium>=1.0.0a1 (from shimmy>=0.2.1)
#   Downloading gymnasium-1.0.0a2-py3-none-any.whl (954 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.3/954.3 kB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=1.0.0a1->shimmy>=0.2.1) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=1.0.0a1->shimmy>=0.2.1) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=1.0.0a1->shimmy>=0.2.1) (0.0.4)
# Installing collected packages: gymnasium, shimmy
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 0.29.1
#     Uninstalling gymnasium-0.29.1:
#       Successfully uninstalled gymnasium-0.29.1
# Successfully installed gymnasium-1.0.0a2 shimmy-2.0.0
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.10/dist-packages (1.0.0a2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (0.0.4)
# ERROR: Invalid requirement: '-'
# Requirement already satisfied: mujoco in /usr/local/lib/python3.10/dist-packages (3.1.6)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from mujoco) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.10/dist-packages (from mujoco) (1.7.0)
# Requirement already satisfied: glfw in /usr/local/lib/python3.10/dist-packages (from mujoco) (2.7.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mujoco) (1.25.2)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.10/dist-packages (from mujoco) (3.1.7)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco) (2023.6.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco) (6.4.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco) (4.12.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco) (3.19.2)
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.3.2-py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.3/182.3 kB 3.6 MB/s eta 0:00:00
# Collecting gymnasium<0.30,>=0.28.1 (from stable-baselines3)
#   Using cached gymnasium-0.29.1-py3-none-any.whl (953 kB)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (1.25.2)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.3.0+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.0.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (3.7.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.15.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.13->stable-baselines3)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.13->stable-baselines3)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.13->stable-baselines3)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.13->stable-baselines3)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.13->stable-baselines3)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.13->stable-baselines3)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.13->stable-baselines3)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.13->stable-baselines3)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.13->stable-baselines3)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.13->stable-baselines3)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.13->stable-baselines3)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13->stable-baselines3)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 39.5 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable-baselines3) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, gymnasium, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stable-baselines3
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 1.0.0a2
#     Uninstalling gymnasium-1.0.0a2:
#       Successfully uninstalled gymnasium-1.0.0a2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# shimmy 2.0.0 requires gymnasium>=1.0.0a1, but you have gymnasium 0.29.1 which is incompatible.
# Successfully installed gymnasium-0.29.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 stable-baselines3-2.3.2
# Requirement already satisfied: stable-baselines3 in /usr/local/lib/python3.10/dist-packages (2.3.2)
# Requirement already satisfied: gym in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.15.2)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (1.25.2)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.3.0+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.0.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (3.7.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym) (0.0.8)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.64.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.6)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (67.7.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2024.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.15.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13->stable-baselines3) (12.5.40)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3) (2024.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard) (3.2.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3) (1.3.0)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 45 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 1s (1,164 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 121925 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting box2d
#   Downloading Box2D-2.3.2.tar.gz (427 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.9/427.9 kB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: box2d
#   Building wheel for box2d (setup.py) ... done
#   Created wheel for box2d: filename=Box2D-2.3.2-cp310-cp310-linux_x86_64.whl size=2367283 sha256=81ad53d6843d4a8efba6d83d7540e3336ac9c8f3a7dc8f857c37147ea8719e9b
#   Stored in directory: /root/.cache/pip/wheels/eb/cb/be/e663f3ce9aba6580611c0febaf7cd3cf7603f87047de2a52f9
# Successfully built box2d
# Installing collected packages: box2d
# Successfully installed box2d-2.3.2
# Requirement already satisfied: gym[box2d] in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym[box2d]) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym[box2d]) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym[box2d]) (0.0.8)
# Collecting box2d-py==2.3.5 (from gym[box2d])
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 6.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pygame==2.1.0 (from gym[box2d])
#   Downloading pygame-2.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 60.5 MB/s eta 0:00:00
# Collecting swig==4.* (from gym[box2d])
#   Downloading swig-4.2.1-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 63.0 MB/s eta 0:00:00
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp310-cp310-linux_x86_64.whl size=2349115 sha256=0fcd35139ce409e7b0c7708db753cbda120925ed2bbf15d7d0fbcb67cbc7dc51
#   Stored in directory: /root/.cache/pip/wheels/db/8f/6a/eaaadf056fba10a98d986f6dce954e6201ba3126926fc5ad9e
# Successfully built box2d-py
# Installing collected packages: swig, box2d-py, pygame
#   Attempting uninstall: pygame
#     Found existing installation: pygame 2.5.2
#     Uninstalling pygame-2.5.2:
#       Successfully uninstalled pygame-2.5.2
# Successfully installed box2d-py-2.3.5 pygame-2.1.0 swig-4.2.1
# Collecting optuna
#   Downloading optuna-3.6.1-py3-none-any.whl (380 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.1/380.1 kB 6.9 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 21.4 MB/s eta 0:00:00
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.30)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.5 alembic-1.13.1 colorlog-6.8.2 optuna-3.6.1

# %%
#Model 1.2: on-policy PPO model (with clipping .4)
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecNormalize
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.utils import set_random_seed
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold
import time
import numpy as np

def create_bipedalwalker_env(seed=None):
    env = make_vec_env('BipedalWalker-v3', n_envs=1, seed=seed)
    env = VecNormalize(env, norm_obs=True, norm_reward=True)
    return env

if __name__ == "__main__":
    seed = 0
    set_random_seed(seed, using_cuda=True)

    print(f"Training PPO model with seed: {seed}")

    #Create the environment
    env = create_bipedalwalker_env(seed)

    #Saving
    env.save(f'BipedalWalker-v3_vecnormalize_seed_{seed}.pkl')

    #Train the agent
    model = PPO("MlpPolicy", env, verbose=1, learning_rate=3e-4, gamma=0.99, gae_lambda=0.95,
                ent_coef=0.01, n_steps=2048, batch_size=256, clip_range=0.4, tensorboard_log="./tb_logs/", seed=seed)

    #Evaluate if the model reaches 300
    callback_on_best = StopTrainingOnRewardThreshold(reward_threshold=300, verbose=1)
    eval_callback = EvalCallback(env, callback_on_new_best=callback_on_best, eval_freq=10000, best_model_save_path='./logs/', log_path='./logs/', deterministic=True, render=False)

    #Time the model
    start_time = time.time()

    #Training
    total_timesteps = 2000000
    model.learn(total_timesteps=total_timesteps, callback=eval_callback, tb_log_name="ppo_bipedalwalker")

    #End timing when done
    end_time = time.time()

    #Calculate time
    training_time = end_time - start_time

    #Save the model
    model.save(f'ppo_bipedalwalker_seed_{seed}')

    #Print the results
    best_score = eval_callback.best_mean_reward
    if best_score < 300:
        print(f"Best score achieved: {best_score}")

    #Reset environment
    env.reset()

    env.training = False
    env.norm_reward = False

    print(f"Completed training PPO model for seed: {seed}")
    print(f"Total training time: {training_time:.2f} seconds")

    #Test model on multiple seeds
    test_seeds = [1, 2, 3, 4, 5]
    test_results = []

    for test_seed in test_seeds:
        set_random_seed(test_seed, using_cuda=True)
        test_env = create_bipedalwalker_env(test_seed)
        obs = test_env.reset()
        total_reward = 0
        done = False
        while not done:
            action, _ = model.predict(obs, deterministic=True)
            obs, reward, done, _ = test_env.step(action)
            total_reward += reward
        test_results.append(total_reward)
        print(f"Test seed: {test_seed}, Total reward: {total_reward}")

    print(f"Average reward across test seeds: {np.mean(test_results)}, Std Dev: {np.std(test_results)}")
# Out:
# Streaminguitvoer ingekort tot de laatste 5000 regels.
# |    loss                 | -0.109     |
# |    n_updates            | 7670       |
# |    policy_gradient_loss | -0.0334    |
# |    std                  | 1.63       |
# |    value_loss           | 0.0416     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 189         |
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 769         |
# |    time_elapsed         | 4002        |
# |    total_timesteps      | 1574912     |
# | train/                  |             |
# |    approx_kl            | 0.033292167 |
# |    clip_fraction        | 0.0823      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.48       |
# |    explained_variance   | 0.392       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.101      |
# |    n_updates            | 7680        |
# |    policy_gradient_loss | -0.0362     |
# |    std                  | 1.62        |
# |    value_loss           | 0.0518      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 998        |
# |    ep_rew_mean          | 186        |
# | time/                   |            |
# |    fps                  | 393        |
# |    iterations           | 770        |
# |    time_elapsed         | 4007       |
# |    total_timesteps      | 1576960    |
# | train/                  |            |
# |    approx_kl            | 0.04144866 |
# |    clip_fraction        | 0.0774     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -7.46      |
# |    explained_variance   | 0.41       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.115     |
# |    n_updates            | 7690       |
# |    policy_gradient_loss | -0.0316    |
# |    std                  | 1.61       |
# |    value_loss           | 0.0578     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+03    |
# |    ep_rew_mean          | 189         |
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 771         |
# |    time_elapsed         | 4010        |
# |    total_timesteps      | 1579008     |
# | train/                  |             |
# |    approx_kl            | 0.040692274 |
# |    clip_fraction        | 0.0896      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.45       |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.088      |
# |    n_updates            | 7700        |
# |    policy_gradient_loss | -0.0379     |
# |    std                  | 1.62        |
# |    value_loss           | 0.114       |
# -----------------------------------------
# Eval num_timesteps=1580000, episode_reward=198.77 +/- 121.58
# Episode length: 902.40 +/- 287.76
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 902         |
# |    mean_reward          | 199         |
# | time/                   |             |
# |    total_timesteps      | 1580000     |
# | train/                  |             |
# |    approx_kl            | 0.047197632 |
# |    clip_fraction        | 0.0974      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.47       |
# |    explained_variance   | -0.263      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0631     |
# |    n_updates            | 7710        |
# |    policy_gradient_loss | -0.0332     |
# |    std                  | 1.63        |
# |    value_loss           | 0.0908      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 188      |
# | time/              |          |
# |    fps             | 393      |
# |    iterations      | 772      |
# |    time_elapsed    | 4020     |
# |    total_timesteps | 1581056  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 187         |
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 773         |
# |    time_elapsed         | 4023        |
# |    total_timesteps      | 1583104     |
# | train/                  |             |
# |    approx_kl            | 0.048398234 |
# |    clip_fraction        | 0.0906      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.49       |
# |    explained_variance   | 0.887       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.109      |
# |    n_updates            | 7720        |
# |    policy_gradient_loss | -0.0299     |
# |    std                  | 1.64        |
# |    value_loss           | 0.0633      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+03    |
# |    ep_rew_mean          | 189         |
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 774         |
# |    time_elapsed         | 4027        |
# |    total_timesteps      | 1585152     |
# | train/                  |             |
# |    approx_kl            | 0.032288313 |
# |    clip_fraction        | 0.0777      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.52       |
# |    explained_variance   | 0.398       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.102      |
# |    n_updates            | 7730        |
# |    policy_gradient_loss | -0.0338     |
# |    std                  | 1.65        |
# |    value_loss           | 0.0581      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 194         |
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 775         |
# |    time_elapsed         | 4031        |
# |    total_timesteps      | 1587200     |
# | train/                  |             |
# |    approx_kl            | 0.035967365 |
# |    clip_fraction        | 0.0839      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.53       |
# |    explained_variance   | 0.491       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.103      |
# |    n_updates            | 7740        |
# |    policy_gradient_loss | -0.0295     |
# |    std                  | 1.65        |
# |    value_loss           | 0.0535      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 194         |
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 776         |
# |    time_elapsed         | 4034        |
# |    total_timesteps      | 1589248     |
# | train/                  |             |
# |    approx_kl            | 0.048289582 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.54       |
# |    explained_variance   | 0.356       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0993     |
# |    n_updates            | 7750        |
# |    policy_gradient_loss | -0.0354     |
# |    std                  | 1.65        |
# |    value_loss           | 0.0679      |
# -----------------------------------------
# Eval num_timesteps=1590000, episode_reward=161.29 +/- 87.73
# Episode length: 913.40 +/- 166.25
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 913         |
# |    mean_reward          | 161         |
# | time/                   |             |
# |    total_timesteps      | 1590000     |
# | train/                  |             |
# |    approx_kl            | 0.038028162 |
# |    clip_fraction        | 0.0864      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.54       |
# |    explained_variance   | 0.426       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.112      |
# |    n_updates            | 7760        |
# |    policy_gradient_loss | -0.0325     |
# |    std                  | 1.66        |
# |    value_loss           | 0.0574      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.02e+03 |
# |    ep_rew_mean     | 196      |
# | time/              |          |
# |    fps             | 393      |
# |    iterations      | 777      |
# |    time_elapsed    | 4044     |
# |    total_timesteps | 1591296  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 196         |
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 778         |
# |    time_elapsed         | 4047        |
# |    total_timesteps      | 1593344     |
# | train/                  |             |
# |    approx_kl            | 0.041588835 |
# |    clip_fraction        | 0.0888      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.54       |
# |    explained_variance   | 0.442       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.117      |
# |    n_updates            | 7770        |
# |    policy_gradient_loss | -0.0317     |
# |    std                  | 1.66        |
# |    value_loss           | 0.0544      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 196         |
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 779         |
# |    time_elapsed         | 4051        |
# |    total_timesteps      | 1595392     |
# | train/                  |             |
# |    approx_kl            | 0.035440397 |
# |    clip_fraction        | 0.081       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.53       |
# |    explained_variance   | 0.452       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.128      |
# |    n_updates            | 7780        |
# |    policy_gradient_loss | -0.0382     |
# |    std                  | 1.65        |
# |    value_loss           | 0.0279      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 780         |
# |    time_elapsed         | 4054        |
# |    total_timesteps      | 1597440     |
# | train/                  |             |
# |    approx_kl            | 0.041172393 |
# |    clip_fraction        | 0.0996      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.51       |
# |    explained_variance   | 0.454       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.11       |
# |    n_updates            | 7790        |
# |    policy_gradient_loss | -0.0355     |
# |    std                  | 1.64        |
# |    value_loss           | 0.0723      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 781         |
# |    time_elapsed         | 4058        |
# |    total_timesteps      | 1599488     |
# | train/                  |             |
# |    approx_kl            | 0.039700143 |
# |    clip_fraction        | 0.0864      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.5        |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0917     |
# |    n_updates            | 7800        |
# |    policy_gradient_loss | -0.0365     |
# |    std                  | 1.64        |
# |    value_loss           | 0.0899      |
# -----------------------------------------
# Eval num_timesteps=1600000, episode_reward=211.05 +/- 105.20
# Episode length: 897.40 +/- 219.13
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 897         |
# |    mean_reward          | 211         |
# | time/                   |             |
# |    total_timesteps      | 1600000     |
# | train/                  |             |
# |    approx_kl            | 0.037318952 |
# |    clip_fraction        | 0.0809      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.52       |
# |    explained_variance   | 0.284       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.108      |
# |    n_updates            | 7810        |
# |    policy_gradient_loss | -0.03       |
# |    std                  | 1.65        |
# |    value_loss           | 0.0625      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.04e+03 |
# |    ep_rew_mean     | 203      |
# | time/              |          |
# |    fps             | 393      |
# |    iterations      | 782      |
# |    time_elapsed    | 4067     |
# |    total_timesteps | 1601536  |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.04e+03   |
# |    ep_rew_mean          | 203        |
# | time/                   |            |
# |    fps                  | 393        |
# |    iterations           | 783        |
# |    time_elapsed         | 4071       |
# |    total_timesteps      | 1603584    |
# | train/                  |            |
# |    approx_kl            | 0.04435541 |
# |    clip_fraction        | 0.0767     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -7.53      |
# |    explained_variance   | 0.944      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.112     |
# |    n_updates            | 7820       |
# |    policy_gradient_loss | -0.0362    |
# |    std                  | 1.65       |
# |    value_loss           | 0.0773     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.04e+03    |
# |    ep_rew_mean          | 203         |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 784         |
# |    time_elapsed         | 4075        |
# |    total_timesteps      | 1605632     |
# | train/                  |             |
# |    approx_kl            | 0.028729849 |
# |    clip_fraction        | 0.0678      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.53       |
# |    explained_variance   | 0.452       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.11       |
# |    n_updates            | 7830        |
# |    policy_gradient_loss | -0.0294     |
# |    std                  | 1.65        |
# |    value_loss           | 0.0592      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | 201         |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 785         |
# |    time_elapsed         | 4078        |
# |    total_timesteps      | 1607680     |
# | train/                  |             |
# |    approx_kl            | 0.041512255 |
# |    clip_fraction        | 0.0886      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.53       |
# |    explained_variance   | 0.449       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0919     |
# |    n_updates            | 7840        |
# |    policy_gradient_loss | -0.0308     |
# |    std                  | 1.65        |
# |    value_loss           | 0.0553      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | 201         |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 786         |
# |    time_elapsed         | 4081        |
# |    total_timesteps      | 1609728     |
# | train/                  |             |
# |    approx_kl            | 0.044199057 |
# |    clip_fraction        | 0.0938      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.51       |
# |    explained_variance   | 0.82        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0214     |
# |    n_updates            | 7850        |
# |    policy_gradient_loss | -0.0328     |
# |    std                  | 1.64        |
# |    value_loss           | 0.191       |
# -----------------------------------------
# Eval num_timesteps=1610000, episode_reward=44.63 +/- 47.31
# Episode length: 644.40 +/- 155.23
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 644        |
# |    mean_reward          | 44.6       |
# | time/                   |            |
# |    total_timesteps      | 1610000    |
# | train/                  |            |
# |    approx_kl            | 0.03280974 |
# |    clip_fraction        | 0.0703     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -7.5       |
# |    explained_variance   | -0.0848    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0679    |
# |    n_updates            | 7860       |
# |    policy_gradient_loss | -0.0279    |
# |    std                  | 1.64       |
# |    value_loss           | 0.0725     |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.03e+03 |
# |    ep_rew_mean     | 198      |
# | time/              |          |
# |    fps             | 394      |
# |    iterations      | 787      |
# |    time_elapsed    | 4089     |
# |    total_timesteps | 1611776  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | 201         |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 788         |
# |    time_elapsed         | 4093        |
# |    total_timesteps      | 1613824     |
# | train/                  |             |
# |    approx_kl            | 0.046094373 |
# |    clip_fraction        | 0.0873      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.51       |
# |    explained_variance   | 0.774       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0174     |
# |    n_updates            | 7870        |
# |    policy_gradient_loss | -0.0264     |
# |    std                  | 1.65        |
# |    value_loss           | 0.263       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | 201         |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 789         |
# |    time_elapsed         | 4096        |
# |    total_timesteps      | 1615872     |
# | train/                  |             |
# |    approx_kl            | 0.029392742 |
# |    clip_fraction        | 0.057       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.53       |
# |    explained_variance   | -0.263      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.084      |
# |    n_updates            | 7880        |
# |    policy_gradient_loss | -0.0278     |
# |    std                  | 1.65        |
# |    value_loss           | 0.0588      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.04e+03    |
# |    ep_rew_mean          | 204         |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 790         |
# |    time_elapsed         | 4100        |
# |    total_timesteps      | 1617920     |
# | train/                  |             |
# |    approx_kl            | 0.036625326 |
# |    clip_fraction        | 0.0665      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.54       |
# |    explained_variance   | 0.51        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.104      |
# |    n_updates            | 7890        |
# |    policy_gradient_loss | -0.0317     |
# |    std                  | 1.65        |
# |    value_loss           | 0.0289      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.04e+03    |
# |    ep_rew_mean          | 204         |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 791         |
# |    time_elapsed         | 4104        |
# |    total_timesteps      | 1619968     |
# | train/                  |             |
# |    approx_kl            | 0.031079609 |
# |    clip_fraction        | 0.0716      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.54       |
# |    explained_variance   | 0.44        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0892     |
# |    n_updates            | 7900        |
# |    policy_gradient_loss | -0.0286     |
# |    std                  | 1.66        |
# |    value_loss           | 0.0505      |
# -----------------------------------------
# Eval num_timesteps=1620000, episode_reward=111.27 +/- 118.19
# Episode length: 740.60 +/- 286.76
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 741         |
# |    mean_reward          | 111         |
# | time/                   |             |
# |    total_timesteps      | 1620000     |
# | train/                  |             |
# |    approx_kl            | 0.035865773 |
# |    clip_fraction        | 0.0669      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.55       |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.105      |
# |    n_updates            | 7910        |
# |    policy_gradient_loss | -0.0307     |
# |    std                  | 1.67        |
# |    value_loss           | 0.0847      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.04e+03 |
# |    ep_rew_mean     | 204      |
# | time/              |          |
# |    fps             | 394      |
# |    iterations      | 792      |
# |    time_elapsed    | 4113     |
# |    total_timesteps | 1622016  |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.02e+03   |
# |    ep_rew_mean          | 197        |
# | time/                   |            |
# |    fps                  | 394        |
# |    iterations           | 793        |
# |    time_elapsed         | 4116       |
# |    total_timesteps      | 1624064    |
# | train/                  |            |
# |    approx_kl            | 0.04054998 |
# |    clip_fraction        | 0.0803     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -7.58      |
# |    explained_variance   | 0.533      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0966    |
# |    n_updates            | 7920       |
# |    policy_gradient_loss | -0.0322    |
# |    std                  | 1.67       |
# |    value_loss           | 0.0537     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.02e+03   |
# |    ep_rew_mean          | 197        |
# | time/                   |            |
# |    fps                  | 394        |
# |    iterations           | 794        |
# |    time_elapsed         | 4119       |
# |    total_timesteps      | 1626112    |
# | train/                  |            |
# |    approx_kl            | 0.03946381 |
# |    clip_fraction        | 0.074      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -7.58      |
# |    explained_variance   | 0.862      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0599    |
# |    n_updates            | 7930       |
# |    policy_gradient_loss | -0.0341    |
# |    std                  | 1.67       |
# |    value_loss           | 0.338      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.03e+03   |
# |    ep_rew_mean          | 199        |
# | time/                   |            |
# |    fps                  | 394        |
# |    iterations           | 795        |
# |    time_elapsed         | 4123       |
# |    total_timesteps      | 1628160    |
# | train/                  |            |
# |    approx_kl            | 0.03892617 |
# |    clip_fraction        | 0.0807     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -7.57      |
# |    explained_variance   | 0.251      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0977    |
# |    n_updates            | 7940       |
# |    policy_gradient_loss | -0.038     |
# |    std                  | 1.67       |
# |    value_loss           | 0.0479     |
# ----------------------------------------
# Eval num_timesteps=1630000, episode_reward=259.68 +/- 2.43
# Episode length: 1037.60 +/- 23.67
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.04e+03    |
# |    mean_reward          | 260         |
# | time/                   |             |
# |    total_timesteps      | 1630000     |
# | train/                  |             |
# |    approx_kl            | 0.044060033 |
# |    clip_fraction        | 0.0858      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.56       |
# |    explained_variance   | 0.0318      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0871     |
# |    n_updates            | 7950        |
# |    policy_gradient_loss | -0.0359     |
# |    std                  | 1.66        |
# |    value_loss           | 0.0903      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.03e+03 |
# |    ep_rew_mean     | 201      |
# | time/              |          |
# |    fps             | 394      |
# |    iterations      | 796      |
# |    time_elapsed    | 4133     |
# |    total_timesteps | 1630208  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | 203         |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 797         |
# |    time_elapsed         | 4137        |
# |    total_timesteps      | 1632256     |
# | train/                  |             |
# |    approx_kl            | 0.039896067 |
# |    clip_fraction        | 0.0922      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.55       |
# |    explained_variance   | 0.329       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0898     |
# |    n_updates            | 7960        |
# |    policy_gradient_loss | -0.036      |
# |    std                  | 1.66        |
# |    value_loss           | 0.0622      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | 202         |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 798         |
# |    time_elapsed         | 4141        |
# |    total_timesteps      | 1634304     |
# | train/                  |             |
# |    approx_kl            | 0.047480226 |
# |    clip_fraction        | 0.0893      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.56       |
# |    explained_variance   | 0.219       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0847     |
# |    n_updates            | 7970        |
# |    policy_gradient_loss | -0.0262     |
# |    std                  | 1.67        |
# |    value_loss           | 0.16        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | 205         |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 799         |
# |    time_elapsed         | 4144        |
# |    total_timesteps      | 1636352     |
# | train/                  |             |
# |    approx_kl            | 0.034096427 |
# |    clip_fraction        | 0.0597      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.57       |
# |    explained_variance   | 0.844       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.116      |
# |    n_updates            | 7980        |
# |    policy_gradient_loss | -0.0305     |
# |    std                  | 1.68        |
# |    value_loss           | 0.109       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.03e+03  |
# |    ep_rew_mean          | 205       |
# | time/                   |           |
# |    fps                  | 394       |
# |    iterations           | 800       |
# |    time_elapsed         | 4147      |
# |    total_timesteps      | 1638400   |
# | train/                  |           |
# |    approx_kl            | 0.0335116 |
# |    clip_fraction        | 0.0714    |
# |    clip_range           | 0.4       |
# |    entropy_loss         | -7.57     |
# |    explained_variance   | 0.23      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0992   |
# |    n_updates            | 7990      |
# |    policy_gradient_loss | -0.0261   |
# |    std                  | 1.67      |
# |    value_loss           | 0.0605    |
# ---------------------------------------
# Eval num_timesteps=1640000, episode_reward=198.07 +/- 125.32
# Episode length: 873.20 +/- 312.68
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 873        |
# |    mean_reward          | 198        |
# | time/                   |            |
# |    total_timesteps      | 1640000    |
# | train/                  |            |
# |    approx_kl            | 0.03278654 |
# |    clip_fraction        | 0.0621     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -7.56      |
# |    explained_variance   | 0.398      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0967    |
# |    n_updates            | 8000       |
# |    policy_gradient_loss | -0.027     |
# |    std                  | 1.67       |
# |    value_loss           | 0.0358     |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.04e+03 |
# |    ep_rew_mean     | 208      |
# | time/              |          |
# |    fps             | 394      |
# |    iterations      | 801      |
# |    time_elapsed    | 4157     |
# |    total_timesteps | 1640448  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.04e+03    |
# |    ep_rew_mean          | 207         |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 802         |
# |    time_elapsed         | 4160        |
# |    total_timesteps      | 1642496     |
# | train/                  |             |
# |    approx_kl            | 0.033425882 |
# |    clip_fraction        | 0.0784      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.55       |
# |    explained_variance   | 0.506       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0994     |
# |    n_updates            | 8010        |
# |    policy_gradient_loss | -0.0301     |
# |    std                  | 1.67        |
# |    value_loss           | 0.0597      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | 206         |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 803         |
# |    time_elapsed         | 4164        |
# |    total_timesteps      | 1644544     |
# | train/                  |             |
# |    approx_kl            | 0.028601538 |
# |    clip_fraction        | 0.049       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.56       |
# |    explained_variance   | 0.822       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0399     |
# |    n_updates            | 8020        |
# |    policy_gradient_loss | -0.0241     |
# |    std                  | 1.68        |
# |    value_loss           | 0.182       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | 206         |
# | time/                   |             |
# |    fps                  | 395         |
# |    iterations           | 804         |
# |    time_elapsed         | 4168        |
# |    total_timesteps      | 1646592     |
# | train/                  |             |
# |    approx_kl            | 0.032122456 |
# |    clip_fraction        | 0.0688      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.57       |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0268     |
# |    n_updates            | 8030        |
# |    policy_gradient_loss | -0.0279     |
# |    std                  | 1.68        |
# |    value_loss           | 0.282       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | 204         |
# | time/                   |             |
# |    fps                  | 395         |
# |    iterations           | 805         |
# |    time_elapsed         | 4171        |
# |    total_timesteps      | 1648640     |
# | train/                  |             |
# |    approx_kl            | 0.046756864 |
# |    clip_fraction        | 0.0706      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.56       |
# |    explained_variance   | 0.0845      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0494     |
# |    n_updates            | 8040        |
# |    policy_gradient_loss | -0.0323     |
# |    std                  | 1.67        |
# |    value_loss           | 0.12        |
# -----------------------------------------
# Eval num_timesteps=1650000, episode_reward=186.01 +/- 87.33
# Episode length: 972.20 +/- 145.31
# ---------------------------------------
# | eval/                   |           |
# |    mean_ep_length       | 972       |
# |    mean_reward          | 186       |
# | time/                   |           |
# |    total_timesteps      | 1650000   |
# | train/                  |           |
# |    approx_kl            | 0.0367354 |
# |    clip_fraction        | 0.0866    |
# |    clip_range           | 0.4       |
# |    entropy_loss         | -7.52     |
# |    explained_variance   | 0.782     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.138     |
# |    n_updates            | 8050      |
# |    policy_gradient_loss | -0.0341   |
# |    std                  | 1.65      |
# |    value_loss           | 0.386     |
# ---------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.03e+03 |
# |    ep_rew_mean     | 204      |
# | time/              |          |
# |    fps             | 394      |
# |    iterations      | 806      |
# |    time_elapsed    | 4181     |
# |    total_timesteps | 1650688  |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.03e+03   |
# |    ep_rew_mean          | 206        |
# | time/                   |            |
# |    fps                  | 394        |
# |    iterations           | 807        |
# |    time_elapsed         | 4185       |
# |    total_timesteps      | 1652736    |
# | train/                  |            |
# |    approx_kl            | 0.04209524 |
# |    clip_fraction        | 0.0791     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -7.51      |
# |    explained_variance   | 0.444      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.108     |
# |    n_updates            | 8060       |
# |    policy_gradient_loss | -0.033     |
# |    std                  | 1.65       |
# |    value_loss           | 0.0493     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.03e+03   |
# |    ep_rew_mean          | 205        |
# | time/                   |            |
# |    fps                  | 395        |
# |    iterations           | 808        |
# |    time_elapsed         | 4188       |
# |    total_timesteps      | 1654784    |
# | train/                  |            |
# |    approx_kl            | 0.04586525 |
# |    clip_fraction        | 0.123      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -7.51      |
# |    explained_variance   | 0.355      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.126     |
# |    n_updates            | 8070       |
# |    policy_gradient_loss | -0.0372    |
# |    std                  | 1.65       |
# |    value_loss           | 0.0542     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | 205         |
# | time/                   |             |
# |    fps                  | 395         |
# |    iterations           | 809         |
# |    time_elapsed         | 4192        |
# |    total_timesteps      | 1656832     |
# | train/                  |             |
# |    approx_kl            | 0.050020326 |
# |    clip_fraction        | 0.0946      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.5        |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0634     |
# |    n_updates            | 8080        |
# |    policy_gradient_loss | -0.035      |
# |    std                  | 1.65        |
# |    value_loss           | 0.114       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.04e+03    |
# |    ep_rew_mean          | 208         |
# | time/                   |             |
# |    fps                  | 395         |
# |    iterations           | 810         |
# |    time_elapsed         | 4196        |
# |    total_timesteps      | 1658880     |
# | train/                  |             |
# |    approx_kl            | 0.029914573 |
# |    clip_fraction        | 0.0551      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.49       |
# |    explained_variance   | 0.928       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.103      |
# |    n_updates            | 8090        |
# |    policy_gradient_loss | -0.0268     |
# |    std                  | 1.65        |
# |    value_loss           | 0.101       |
# -----------------------------------------
# Eval num_timesteps=1660000, episode_reward=169.04 +/- 128.19
# Episode length: 869.20 +/- 336.23
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 869         |
# |    mean_reward          | 169         |
# | time/                   |             |
# |    total_timesteps      | 1660000     |
# | train/                  |             |
# |    approx_kl            | 0.045467973 |
# |    clip_fraction        | 0.0972      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.49       |
# |    explained_variance   | 0.336       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0871     |
# |    n_updates            | 8100        |
# |    policy_gradient_loss | -0.0361     |
# |    std                  | 1.65        |
# |    value_loss           | 0.0636      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.03e+03 |
# |    ep_rew_mean     | 208      |
# | time/              |          |
# |    fps             | 394      |
# |    iterations      | 811      |
# |    time_elapsed    | 4205     |
# |    total_timesteps | 1660928  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.04e+03    |
# |    ep_rew_mean          | 210         |
# | time/                   |             |
# |    fps                  | 395         |
# |    iterations           | 812         |
# |    time_elapsed         | 4209        |
# |    total_timesteps      | 1662976     |
# | train/                  |             |
# |    approx_kl            | 0.047017545 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.48       |
# |    explained_variance   | 0.532       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.101      |
# |    n_updates            | 8110        |
# |    policy_gradient_loss | -0.04       |
# |    std                  | 1.64        |
# |    value_loss           | 0.046       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.04e+03    |
# |    ep_rew_mean          | 211         |
# | time/                   |             |
# |    fps                  | 395         |
# |    iterations           | 813         |
# |    time_elapsed         | 4212        |
# |    total_timesteps      | 1665024     |
# | train/                  |             |
# |    approx_kl            | 0.041838266 |
# |    clip_fraction        | 0.0738      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.48       |
# |    explained_variance   | 0.328       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0966     |
# |    n_updates            | 8120        |
# |    policy_gradient_loss | -0.0288     |
# |    std                  | 1.65        |
# |    value_loss           | 0.0797      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.04e+03   |
# |    ep_rew_mean          | 209        |
# | time/                   |            |
# |    fps                  | 395        |
# |    iterations           | 814        |
# |    time_elapsed         | 4215       |
# |    total_timesteps      | 1667072    |
# | train/                  |            |
# |    approx_kl            | 0.03987983 |
# |    clip_fraction        | 0.0834     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -7.51      |
# |    explained_variance   | 0.918      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.118     |
# |    n_updates            | 8130       |
# |    policy_gradient_loss | -0.0284    |
# |    std                  | 1.66       |
# |    value_loss           | 0.135      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.04e+03   |
# |    ep_rew_mean          | 212        |
# | time/                   |            |
# |    fps                  | 395        |
# |    iterations           | 815        |
# |    time_elapsed         | 4219       |
# |    total_timesteps      | 1669120    |
# | train/                  |            |
# |    approx_kl            | 0.03374697 |
# |    clip_fraction        | 0.0708     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -7.53      |
# |    explained_variance   | 0.77       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0299     |
# |    n_updates            | 8140       |
# |    policy_gradient_loss | -0.0308    |
# |    std                  | 1.66       |
# |    value_loss           | 0.289      |
# ----------------------------------------
# Eval num_timesteps=1670000, episode_reward=222.84 +/- 69.66
# Episode length: 975.80 +/- 122.54
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 976        |
# |    mean_reward          | 223        |
# | time/                   |            |
# |    total_timesteps      | 1670000    |
# | train/                  |            |
# |    approx_kl            | 0.04011176 |
# |    clip_fraction        | 0.0932     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -7.54      |
# |    explained_variance   | 0.809      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0471    |
# |    n_updates            | 8150       |
# |    policy_gradient_loss | -0.0321    |
# |    std                  | 1.67       |
# |    value_loss           | 0.282      |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.04e+03 |
# |    ep_rew_mean     | 212      |
# | time/              |          |
# |    fps             | 395      |
# |    iterations      | 816      |
# |    time_elapsed    | 4228     |
# |    total_timesteps | 1671168  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | 208         |
# | time/                   |             |
# |    fps                  | 395         |
# |    iterations           | 817         |
# |    time_elapsed         | 4233        |
# |    total_timesteps      | 1673216     |
# | train/                  |             |
# |    approx_kl            | 0.040737323 |
# |    clip_fraction        | 0.0778      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.54       |
# ...
# | train/                  |             |
# |    approx_kl            | 0.034305044 |
# |    clip_fraction        | 0.0669      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -8.13       |
# |    explained_variance   | 0.88        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00606    |
# |    n_updates            | 9610        |
# |    policy_gradient_loss | -0.0345     |
# |    std                  | 1.98        |
# |    value_loss           | 0.35        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 937      |
# |    ep_rew_mean     | 168      |
# | time/              |          |
# |    fps             | 400      |
# |    iterations      | 962      |
# |    time_elapsed    | 4919     |
# |    total_timesteps | 1970176  |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 938        |
# |    ep_rew_mean          | 168        |
# | time/                   |            |
# |    fps                  | 400        |
# |    iterations           | 963        |
# |    time_elapsed         | 4923       |
# |    total_timesteps      | 1972224    |
# | train/                  |            |
# |    approx_kl            | 0.05481988 |
# |    clip_fraction        | 0.103      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -8.14      |
# |    explained_variance   | 0.46       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0252    |
# |    n_updates            | 9620       |
# |    policy_gradient_loss | -0.0359    |
# |    std                  | 1.97       |
# |    value_loss           | 0.241      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 949         |
# |    ep_rew_mean          | 173         |
# | time/                   |             |
# |    fps                  | 400         |
# |    iterations           | 964         |
# |    time_elapsed         | 4926        |
# |    total_timesteps      | 1974272     |
# | train/                  |             |
# |    approx_kl            | 0.043329295 |
# |    clip_fraction        | 0.0936      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -8.13       |
# |    explained_variance   | 0.0595      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.136      |
# |    n_updates            | 9630        |
# |    policy_gradient_loss | -0.0375     |
# |    std                  | 1.97        |
# |    value_loss           | 0.0351      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 953        |
# |    ep_rew_mean          | 174        |
# | time/                   |            |
# |    fps                  | 400        |
# |    iterations           | 965        |
# |    time_elapsed         | 4931       |
# |    total_timesteps      | 1976320    |
# | train/                  |            |
# |    approx_kl            | 0.03779216 |
# |    clip_fraction        | 0.0528     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -8.11      |
# |    explained_variance   | 0.141      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0828    |
# |    n_updates            | 9640       |
# |    policy_gradient_loss | -0.0317    |
# |    std                  | 1.95       |
# |    value_loss           | 0.0661     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 953         |
# |    ep_rew_mean          | 174         |
# | time/                   |             |
# |    fps                  | 400         |
# |    iterations           | 966         |
# |    time_elapsed         | 4934        |
# |    total_timesteps      | 1978368     |
# | train/                  |             |
# |    approx_kl            | 0.039356846 |
# |    clip_fraction        | 0.0832      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -8.08       |
# |    explained_variance   | 0.49        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.131      |
# |    n_updates            | 9650        |
# |    policy_gradient_loss | -0.0332     |
# |    std                  | 1.95        |
# |    value_loss           | 0.0434      |
# -----------------------------------------
# Eval num_timesteps=1980000, episode_reward=46.75 +/- 173.86
# Episode length: 458.00 +/- 447.05
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 458         |
# |    mean_reward          | 46.8        |
# | time/                   |             |
# |    total_timesteps      | 1980000     |
# | train/                  |             |
# |    approx_kl            | 0.039416682 |
# |    clip_fraction        | 0.0945      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -8.09       |
# |    explained_variance   | 0.336       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.106      |
# |    n_updates            | 9660        |
# |    policy_gradient_loss | -0.0377     |
# |    std                  | 1.96        |
# |    value_loss           | 0.0532      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 953      |
# |    ep_rew_mean     | 174      |
# | time/              |          |
# |    fps             | 400      |
# |    iterations      | 967      |
# |    time_elapsed    | 4940     |
# |    total_timesteps | 1980416  |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 949        |
# |    ep_rew_mean          | 173        |
# | time/                   |            |
# |    fps                  | 400        |
# |    iterations           | 968        |
# |    time_elapsed         | 4945       |
# |    total_timesteps      | 1982464    |
# | train/                  |            |
# |    approx_kl            | 0.03265402 |
# |    clip_fraction        | 0.072      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -8.1       |
# |    explained_variance   | 0.493      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.135     |
# |    n_updates            | 9670       |
# |    policy_gradient_loss | -0.0291    |
# |    std                  | 1.97       |
# |    value_loss           | 0.0281     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 957         |
# |    ep_rew_mean          | 176         |
# | time/                   |             |
# |    fps                  | 401         |
# |    iterations           | 969         |
# |    time_elapsed         | 4948        |
# |    total_timesteps      | 1984512     |
# | train/                  |             |
# |    approx_kl            | 0.036561064 |
# |    clip_fraction        | 0.0633      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -8.12       |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.108      |
# |    n_updates            | 9680        |
# |    policy_gradient_loss | -0.0364     |
# |    std                  | 1.97        |
# |    value_loss           | 0.0951      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 955         |
# |    ep_rew_mean          | 175         |
# | time/                   |             |
# |    fps                  | 401         |
# |    iterations           | 970         |
# |    time_elapsed         | 4951        |
# |    total_timesteps      | 1986560     |
# | train/                  |             |
# |    approx_kl            | 0.055762824 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -8.14       |
# |    explained_variance   | 0.25        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0979     |
# |    n_updates            | 9690        |
# |    policy_gradient_loss | -0.035      |
# |    std                  | 1.99        |
# |    value_loss           | 0.0632      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 948         |
# |    ep_rew_mean          | 172         |
# | time/                   |             |
# |    fps                  | 401         |
# |    iterations           | 971         |
# |    time_elapsed         | 4955        |
# |    total_timesteps      | 1988608     |
# | train/                  |             |
# |    approx_kl            | 0.034859564 |
# |    clip_fraction        | 0.0616      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -8.15       |
# |    explained_variance   | 0.9         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.062      |
# |    n_updates            | 9700        |
# |    policy_gradient_loss | -0.0328     |
# |    std                  | 1.99        |
# |    value_loss           | 0.175       |
# -----------------------------------------
# Eval num_timesteps=1990000, episode_reward=190.53 +/- 81.70
# Episode length: 983.20 +/- 168.15
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 983         |
# |    mean_reward          | 191         |
# | time/                   |             |
# |    total_timesteps      | 1990000     |
# | train/                  |             |
# |    approx_kl            | 0.038779132 |
# |    clip_fraction        | 0.0724      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -8.15       |
# |    explained_variance   | 0.857       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0845     |
# |    n_updates            | 9710        |
# |    policy_gradient_loss | -0.0326     |
# |    std                  | 1.99        |
# |    value_loss           | 0.186       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 944      |
# |    ep_rew_mean     | 170      |
# | time/              |          |
# |    fps             | 400      |
# |    iterations      | 972      |
# |    time_elapsed    | 4965     |
# |    total_timesteps | 1990656  |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 945        |
# |    ep_rew_mean          | 170        |
# | time/                   |            |
# |    fps                  | 401        |
# |    iterations           | 973        |
# |    time_elapsed         | 4969       |
# |    total_timesteps      | 1992704    |
# | train/                  |            |
# |    approx_kl            | 0.05517807 |
# |    clip_fraction        | 0.115      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -8.14      |
# |    explained_variance   | 0.86       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.064     |
# |    n_updates            | 9720       |
# |    policy_gradient_loss | -0.0411    |
# |    std                  | 1.98       |
# |    value_loss           | 0.246      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 955         |
# |    ep_rew_mean          | 174         |
# | time/                   |             |
# |    fps                  | 401         |
# |    iterations           | 974         |
# |    time_elapsed         | 4973        |
# |    total_timesteps      | 1994752     |
# | train/                  |             |
# |    approx_kl            | 0.034653828 |
# |    clip_fraction        | 0.0729      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -8.14       |
# |    explained_variance   | 0.898       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0683     |
# |    n_updates            | 9730        |
# |    policy_gradient_loss | -0.033      |
# |    std                  | 1.98        |
# |    value_loss           | 0.229       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 963        |
# |    ep_rew_mean          | 177        |
# | time/                   |            |
# |    fps                  | 401        |
# |    iterations           | 975        |
# |    time_elapsed         | 4976       |
# |    total_timesteps      | 1996800    |
# | train/                  |            |
# |    approx_kl            | 0.05909688 |
# |    clip_fraction        | 0.121      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -8.13      |
# |    explained_variance   | 0.256      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.138     |
# |    n_updates            | 9740       |
# |    policy_gradient_loss | -0.0365    |
# |    std                  | 1.98       |
# |    value_loss           | 0.0557     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 973         |
# |    ep_rew_mean          | 181         |
# | time/                   |             |
# |    fps                  | 401         |
# |    iterations           | 976         |
# |    time_elapsed         | 4979        |
# |    total_timesteps      | 1998848     |
# | train/                  |             |
# |    approx_kl            | 0.032610662 |
# |    clip_fraction        | 0.0594      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -8.13       |
# |    explained_variance   | 0.464       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.124      |
# |    n_updates            | 9750        |
# |    policy_gradient_loss | -0.0286     |
# |    std                  | 1.98        |
# |    value_loss           | 0.0502      |
# -----------------------------------------
# Eval num_timesteps=2000000, episode_reward=196.94 +/- 115.35
# Episode length: 916.00 +/- 276.02
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 916         |
# |    mean_reward          | 197         |
# | time/                   |             |
# |    total_timesteps      | 2000000     |
# | train/                  |             |
# |    approx_kl            | 0.037646025 |
# |    clip_fraction        | 0.0659      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -8.15       |
# |    explained_variance   | 0.498       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0999     |
# |    n_updates            | 9760        |
# |    policy_gradient_loss | -0.0303     |
# |    std                  | 1.99        |
# |    value_loss           | 0.0503      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 973      |
# |    ep_rew_mean     | 181      |
# | time/              |          |
# |    fps             | 400      |
# |    iterations      | 977      |
# |    time_elapsed    | 4990     |
# |    total_timesteps | 2000896  |
# ---------------------------------
# Best score achieved: 267.93558640000003
# Completed training PPO model for seed: 0
# Total training time: 4990.55 seconds
# Test seed: 1, Total reward: [-36.94526]
# Test seed: 2, Total reward: [-34.490753]
# Test seed: 3, Total reward: [-34.35621]
# Test seed: 4, Total reward: [-35.61888]
# Test seed: 5, Total reward: [-35.789227]
# Average reward across test seeds: -35.440067291259766, Std Dev: 0.9482020139694214
